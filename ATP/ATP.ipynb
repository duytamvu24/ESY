# %%
import numpy as np
import pandas as pd
from collections import Counter
import random
# Anzahl der Personen
excel = pd.read_excel("Kopie von Umfrage für HT Trai He 2024 (Antworten).xlsx", engine = "openpyxl")
pd.set_option('mode.chained_assignment', None)

excel.columns.to_list()
name = ["Vorname", "Name"]
orga = "Ich möchte folgende Rolle bei Trại Hè 2024 übernehmen"
options = ["Vorname", "Name", "Ich möchte folgende Rolle bei Trại Hè 2024 übernehmen",
    "Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Ich finde alle cool (suprise Đội ule)]",
            'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Berna]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Ellie]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Thanh Tam]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Andy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Nhat-Huy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Thien An]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Hảo-Thơ]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Tram-Anh]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Teresa Ngan]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Ngoc Anh/ Anni]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Don]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Ngan Ha]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Minh Huy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Vincent]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Nhu Ha]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Van]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Minh]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Kiet]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Duc]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Martin Tinh]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Thi Trâm-Anh]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Gia-Huy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Tam Dan]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Tai]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Lam Quy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Thang Dominik]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Quynh Chi]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Michelle]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Duy Tam]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Viet Huy]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Tram]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Duc An]',
 'Mit welchen Personen kannst du dir vorstellen eine Đội zu leiten? Ihr könnt so viele Personen auswählen wie ihr wollt. [Giang]',
          ]

excel = excel[options]
excel = excel.iloc[4:, :]
excel = excel.fillna(0)

#bennene die spalten um
your_function = lambda col: col.split("[", 1)[-1].split(']', 1)[0]
l = excel.columns.to_list()[3:]
l_names = [your_function(el) for el in l]

excel.columns = list(excel.columns[:3]) + l_names
l_names = l_names[1:]

#Manuelle Liste der Jungs und Mädchen
m_l = ["Berna", "Ellie", "Thien An", "Hảo-Thơ", "Tram-Anh", "Teresa Ngan", "Ngoc Anh/ Anni", "Ngan Ha",'Nhu Ha',
 'Van','Thi Trâm-Anh','Quynh Chi',
 'Michelle','Tram',]
j_l = ['Thanh Tam',
 'Andy',
 'Nhat-Huy', 'Don', 'Minh Huy',
 'Vincent','Minh',
 'Kiet',
 'Duc',
 'Martin Tinh','Gia-Huy',
 'Tam Dan',
 'Tai',
 'Lam Quy',
 'Thang Dominik','Duy Tam', 'Duc An',]

#Kiet zusätzlich einfügen
new_row = {'Vorname': 'Kiet', 'Ich möchte folgende Rolle bei Trại Hè 2024 übernehmen': 'Huynh Trưởng für eine Đội', 'Ich finde alle cool (suprise Đội ule)': 1.0}
excel["Vorname"].astype(str)


# droppe teilnehmer, die orga machen wollen
excel.loc[excel['Vorname'] == 'Martin Thinh ', 'Vorname'] = 'Martin Tinh'
excel.loc[excel['Vorname'] == 'Nhat-Huy ', 'Vorname'] = 'Nhat-Huy'
excel.loc[excel['Vorname'] == 'Duy Tam ', 'Vorname'] = 'Duy Tam'
excel.loc[excel['Vorname'] == 'Quynh Chi ', 'Vorname'] = 'Quynh Chi'
excel.loc[excel['Vorname'] == 'Bernadette', 'Vorname'] = 'Berna'
excel.loc[excel['Vorname'] == 'Bernadette ', 'Vorname'] = 'Berna'
excel.loc[excel['Vorname'] == 'Andy Minh', 'Vorname'] = 'Andy'
excel.loc[excel['Vorname'] == 'Dominik Duc Minh', 'Vorname'] = 'Minh'
excel.loc[excel['Vorname'] == 'Dominik / Thang', 'Vorname'] = 'Thang Dominik'
excel.loc[excel['Vorname'] == 'Ngoc Anh ', 'Vorname'] = 'Ngoc Anh/ Anni'
excel.loc[(excel['Vorname'] == 'Nguyen ') & (excel["Name"] == "Van"), 'Vorname'] = 'Van'
excel.loc[(excel['Vorname'] == 'Trinh') & (excel["Name"] == "Gia-Huy-Jan"), 'Vorname'] = 'Gia-Huy'
excel.loc[(excel['Vorname'] == 'Nguyen') & (excel["Name"] == "Teresa Ngân"), 'Vorname'] = 'Teresa Ngan'
excel.loc[excel['Vorname'] == 'Amanda Ngoc Tram', 'Vorname'] = 'Tram'
excel.loc[excel['Vorname'] == 'Thi Trâm Anh', 'Vorname'] = 'Thi Trâm-Anh'
excel.loc[excel['Vorname'] == 'Anh Duc ', 'Vorname'] = 'Duc'
excel.loc[excel['Vorname'] == 'ngan.ha090301@gmail.com', 'Vorname'] = 'Ngan Ha'
"""excel.loc[excel['Vorname'] == 'Minh Huy', 'Ich finde alle cool (suprise Đội ule)'] = 1
excel.loc[excel['Vorname'] == 'Ngan Ha', 'Ich finde alle cool (suprise Đội ule)'] = 1
excel.loc[excel['Vorname'] == 'Duy Tam', 'Ich finde alle cool (suprise Đội ule)'] = 1
excel.loc[excel["Vorname"] == "Martin Tinh", "Ich finde alle cool (suprise Đội ule)"] = 1.0"""
duplicated_names = excel['Vorname'].duplicated(keep='last')



# Löschen des ersten Vorkommens der doppelten Namen
excel = excel[~duplicated_names]

excel['Vorname'] = pd.Categorical(excel['Vorname'], categories=l_names, ordered=True)
excel = excel.sort_values('Vorname')

# Methode 1: Verwenden von loc
excel = excel.append(new_row, ignore_index=True)
condition_column = 'Ich finde alle cool (suprise Đội ule)'

# Bedingung: Wenn in Spalte 'A' eine 1 steht
condition = (excel[condition_column] == 1) | (excel[condition_column] == 'Ich finde alle cool (suprise Đội ule)')

combined_list = []

combined_list.extend(j_l)
combined_list.extend(m_l)
excel.loc[condition, combined_list] = 1

excel = excel.drop(columns = ['Giang', 'Viet Huy'])

# falls orga, nehme diese personen raus aus den spalten
condition_column = 'Ich möchte folgende Rolle bei Trại Hè 2024 übernehmen'
condition = excel[condition_column] == 'Orga-Team'
orga = excel.loc[condition]
orga = orga["Vorname"].to_list()
excel = excel.drop(columns = orga, axis=1)
# Droppe die Zeilen, deren Namen in names_to_drop enthalten sind
excel = excel[~excel['Vorname'].isin(orga)].reset_index()


excel = excel[['Vorname',
 'Name',           
 'Ich möchte folgende Rolle bei Trại Hè 2024 übernehmen',
 'Ich finde alle cool (suprise Đội ule)',
 'Berna',
 'Thanh Tam',
 'Andy',
 'Thien An',
 'Hảo-Thơ',
 'Teresa Ngan',
 'Ngoc Anh/ Anni',
 'Don',
 'Ngan Ha',
 'Minh Huy',
 'Vincent',
 'Nhu Ha',
 'Minh',
 'Duc',
 'Martin Tinh',
 'Thi Trâm-Anh',
 'Gia-Huy',
 'Tam Dan',
 'Tai',
 'Lam Quy',
 'Thang Dominik',
 'Quynh Chi',
 'Michelle',
 'Duy Tam',
 'Tram',
 'Duc An',
 'Kiet',]]

l_names = excel.iloc[:, 4:].columns.to_list()
matrix = excel.iloc[:, 4:].to_numpy()
# Ermittle Teankonstellation bei n Teilnehmern, m Mädchen und J Jungs:
auft = []
n = len(excel["Vorname"].to_list())
n_g_m = n % 3
n_g = int(n/3)
m = 15
j = 18

# Bilde n_g j_m Paare. Voraussetzung: j oder m >= n_g
if n_g_m == 0:
    print("nur 3-er Gruppe")
elif n_g_m == 1:
    print("eine 4-er Gruppe, Rest 3-er Gruppe")
else:
    print("zwei 4-er Gruppen, Rest 3-er Gruppe")
    
#Iwie schwer umzusetzen, d.h. manuell eingeben

transposed_A = matrix.T
Score_A = matrix + transposed_A

#excel.fillna(0, inplace=True)
#act_matrix = excel.iloc[:, 4:].values
df2 = pd.DataFrame({"Spieler":l_names})

Score = np.sum(Score_A, axis=1)

#Erstelle dataframe mit Punktzahl und Matches. Darauf basiert dann die Reihenfolge der Teamerstellung
df2["Matches"] = [Counter(Score_A[i])[2] for i in range(len(matrix))]
df2["Punktzahl"] = np.sum(matrix, axis=0)
#Wahlscore ist Matches/gesamtePunktzahl
df2["WahlScore"] = df2["Matches"]/np.sum(matrix, axis=0)
#
df2["gewähltScore"] = df2["Matches"]/np.sum(matrix, axis=1)
df2 = df2.sort_values(by='WahlScore', ascending=False)
df2

Score = np.sum(Score_A, axis=1)

df = pd.DataFrame({'Punktzahl': Score, 'Spieler': range(1, len(Score)+1)})

# Sortieren des DataFrames nach der Punktzahl
df = df.sort_values(by='Punktzahl', ascending=False)
pairs = []
#Erstelle n_g Paare für die erste Iteration
for i in range(n_g):
    print("Iteration: " + str(i))
    #Dynamische Teilnehmer
    df_j = df2[df2["Spieler"].isin(j_l)]
    df_m = df2[df2["Spieler"].isin(m_l)]
    m_l_i = df2[df2['Spieler'].isin(m_l)].index.tolist()
    j_l_i = df2[df2['Spieler'].isin(j_l)].index.tolist()
    ind = []
    #j mit niedrigstem Matches: weil mehr jungs als mädels
    lowest_score_index = df_j['Matches'].idxmin()
    #print(df_j[["Spieler", "Matches"]])
    # Matches bestimmen und random match wählen
    matches = Score_A[lowest_score_index]
    for j in range(len(matches)):
        if matches[j] == 2:
            ind.append(j)
        else:
            ind = ind
    
    spieler_matches = [x for x in ind if x in m_l_i]
    if len(spieler_matches) == 0:
        print("Zu Person " + str(lowest_score_index) + " gibt es keine Matches!")
        print(pairs)
        print("Teile die Teams neu ein, indem du das Programm neu durchführst!")
        break
    match_index = random.choice(spieler_matches)
    match = df2.loc[match_index]
    pairs.append([lowest_score_index , match_index])


    #Entferne diesen aus df2
    df2 = df2.drop(match_index)
    df2 = df2.drop(lowest_score_index)
    
# Zweite Iteration: Die Paare gelten jetzt als die Basis eines Teams, dementsprechend werden auch die Votes für das Team angepasst.
# Es gibt jetzt ein Team-Score, der dann benutzt wird, um die restlichen 11 in die Gruppen einzuteilen.
rest_list = df2.index.to_list()
    
pair_matrix = []

for i in range(n_g):
    duo_to_choose_one_matrix = [matrix[j] for j in rest_list]
    duo_to_choose_one_matrix = np.array(duo_to_choose_one_matrix)
    duo_to_choose_one_matrix = duo_to_choose_one_matrix[:, pairs[i]]
    pair_votes = duo_to_choose_one_matrix.sum(axis = 1)
    pair_matrix.append(pair_votes)
pair_matrix = np.array(pair_matrix)

rest_matrix = matrix[:, rest_list] # spalte rest wählt team zeile
rest_team_matrix = []
for i in range(n_g):
    rest_chooses_team = rest_matrix[pairs[i]].sum(axis = 0)
    rest_team_matrix.append(rest_chooses_team)
rest_team_matrix = np.array(rest_team_matrix)

pair_matrix = rest_team_matrix + pair_matrix

#berechne nun score des Teams und matche diesen mit dem niedrigsten Score aus rest
paare = [[l_names[pairs[i][0]], l_names[pairs[i][1]]] for i in range(len(pairs))]
df_pair = pd.DataFrame({"Team": paare})
df_pair["Team_score"] = np.sum(pair_matrix, axis=1)
df_pair_3 = [Counter(pair_matrix[i])[3] for i in range(len(pair_matrix))]
df_pair_4 = [Counter(pair_matrix[i])[4] for i in range(len(pair_matrix))]
df_pair["Matches"] = [(df_pair_3[i] + df_pair_4[i]) for i in range(len(pair_matrix))]
df_pair = df_pair.sort_values(by='Team_score', ascending=False)

import random

#Ermittle Matches nach obigen Algorithmus
final_team = []
for i in range(n_g):
    team = []
    #nehme zuerst die Person mit dem niedrigsten Score
    lowest_score_index = df_pair['Team_score'].idxmin()
    matches = np.where((pair_matrix[lowest_score_index] == 4) | (pair_matrix[lowest_score_index] == 3))[0]
    if len(matches) == 0:
        print("Zu Person " + str(i) + " gibt es keine Matches!")
        break
    final_memb_index = random.choice(matches)
    name_final_memb_index = rest_list[final_memb_index]
    print("Das entspricht spieler mit ID: " + str(final_memb_index))
    team.append(df_pair.loc[lowest_score_index]["Team"][0])
    team.append(df_pair.loc[lowest_score_index]["Team"][1])
    team.append(l_names[name_final_memb_index])
    final_team.append(team)
    df_pair = df_pair.drop(lowest_score_index)
    pair_matrix[:, final_memb_index] = 0  # Setze alle Werte der Spalte (rest) auf 0, damit kein Match mit ihm gefunden wird
    
    
    
# zähle die übrigen noch dazu
for i in range(len(df_pair)):
    final_team.append(df_pair["Team"].to_list()[i])

print("Hier ist die erste Zusammenstellung des Teams: ")
print(final_team)
# Out:
# nur 3-er Gruppe
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Das entspricht spieler mit ID: 5
# Das entspricht spieler mit ID: 3
# Das entspricht spieler mit ID: 2
# Das entspricht spieler mit ID: 1
# Das entspricht spieler mit ID: 6
# Das entspricht spieler mit ID: 0
# Das entspricht spieler mit ID: 4
# Zu Person 7 gibt es keine Matches!
# Hier ist die erste Zusammenstellung des Teams:
# [['Don', 'Teresa Ngan', 'Duy Tam'], ['Duc An', 'Hảo-Thơ', 'Tai'], ['Duc', 'Berna', 'Martin Tinh'], ['Gia-Huy', 'Nhu Ha', 'Thang Dominik'], ['Vincent', 'Ngoc Anh/ Anni', 'Minh'], ['Thanh Tam', 'Tram', 'Kiet'], ['Minh Huy', 'Thien An', 'Andy'], ['Lam Quy', 'Michelle'], ['Tam Dan', 'Quynh Chi']]
